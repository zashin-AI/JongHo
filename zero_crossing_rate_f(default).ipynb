# %%
import librosa
y, sr = librosa.load('C:/nmb/nmb_data/testvoice_F2.wav')
print(y)
print(y.shape)
print(len(y))
a = librosa.feature.zero_crossing_rate(y=y)
print(a.shape)  # 
print(a[0])
print(len(a[0]))
# Out:
# [-2.9244100e-05 -7.4235257e-05 -9.4395844e-05 ...  6.2298583e-04
#  -1.2165480e-03 -4.3098307e-03]
# (110250,)
# 110250
# (1, 216)
# [0.01171875 0.01269531 0.01806641 0.01611328 0.01708984 0.02294922
#  0.02001953 0.02490234 0.06835938 0.14160156 0.24316406 0.27539062
#  0.24072266 0.17773438 0.09521484 0.0703125  0.07080078 0.06494141
#  0.06542969 0.07177734 0.07861328 0.08349609 0.07666016 0.06591797
#  0.05957031 0.06542969 0.07519531 0.08837891 0.09326172 0.09179688
#  0.09082031 0.08496094 0.08105469 0.07421875 0.06152344 0.05322266
#  0.04492188 0.05078125 0.0625     0.07910156 0.09375    0.09375
#  0.08398438 0.06689453 0.05126953 0.04638672 0.04345703 0.04248047
#  0.04345703 0.03857422 0.04052734 0.04150391 0.03759766 0.03222656
#  0.02880859 0.04345703 0.05859375 0.07470703 0.08496094 0.07324219
#  0.06445312 0.05419922 0.04638672 0.05761719 0.05615234 0.06201172
#  0.06933594 0.06396484 0.07177734 0.06933594 0.05957031 0.05078125
#  0.04589844 0.04492188 0.04638672 0.05224609 0.05126953 0.04541016
#  0.04589844 0.04101562 0.03369141 0.03076172 0.03320312 0.02783203
#  0.03076172 0.03417969 0.03027344 0.03076172 0.02832031 0.03320312
#  0.03759766 0.04394531 0.05078125 0.05273438 0.05029297 0.05224609
#  0.05957031 0.05761719 0.06152344 0.06201172 0.05322266 0.04882812
#  0.04638672 0.04248047 0.04003906 0.03710938 0.03222656 0.03320312
#  0.03710938 0.04150391 0.04003906 0.03369141 0.03417969 0.03857422
#  0.03955078 0.04248047 0.04199219 0.03955078 0.0390625  0.04052734
#  0.03613281 0.03222656 0.11914062 0.20117188 0.24169922 0.25390625
#  0.171875   0.08544922 0.04541016 0.04150391 0.04785156 0.05322266
#  0.05566406 0.05126953 0.04833984 0.05664062 0.06494141 0.07421875
#  0.07910156 0.07568359 0.07910156 0.08007812 0.07910156 0.07861328
#  0.0703125  0.05957031 0.046875   0.03662109 0.03173828 0.02929688
#  0.03955078 0.05078125 0.06005859 0.06689453 0.06396484 0.05761719
#  0.05175781 0.04541016 0.04150391 0.04101562 0.03710938 0.03857422
#  0.046875   0.04833984 0.04638672 0.04199219 0.03369141 0.03564453
#  0.03808594 0.04199219 0.04199219 0.04150391 0.04882812 0.05419922
#  0.05859375 0.05810547 0.05957031 0.08203125 0.08105469 0.07861328
#  0.06787109 0.04345703 0.05273438 0.06152344 0.06542969 0.07177734
#  0.07226562 0.08203125 0.08740234 0.07714844 0.06347656 0.04833984
#  0.04345703 0.04785156 0.05126953 0.05224609 0.04833984 0.04492188
#  0.03759766 0.03076172 0.03613281 0.03076172 0.03320312 0.03613281
#  0.03222656 0.03662109 0.03662109 0.03320312 0.03662109 0.03320312
#  0.03076172 0.02978516 0.02246094 0.02587891 0.02148438 0.01708984]
# 216

# %%
zero_crossings = librosa.zero_crossings(y, pad=False)

print(zero_crossings)
print(sum(zero_crossings))
# Out:
# [False False False ... False  True False]
# 6492

# %%
import matplotlib.pyplot as plt
n0 = 0
n1 = 110250

plt.figure(figsize=(16, 6))
# plt.title('zero_crossings_f')
plt.title('zero_crossing_rate')
plt.plot(y[n0:n1])   # zero_crossings 

plt.grid()

plt.figure(figsize=(16, 6))
plt.title('zero_crossing_rate_f')   
plt.plot(a[0])       # zero_crossing_rate -> 음의 높낮이를 확인할수 있다.   
plt.grid()

plt.show()
