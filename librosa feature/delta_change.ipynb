# %%
import librosa
import librosa.display

y, sr = librosa.load('C:/nmb/nmb_data/testvoice_F2.wav')
mfcc = librosa.feature.mfcc(y=y, sr=sr)
mfcc_delta = librosa.feature.delta(mfcc)
print(mfcc_delta)
print(mfcc_delta.shape) # (20, 216)
# Out:
# [[ 3.6097605   3.6097605   3.6097605  ... -0.672464   -0.672464
#   -0.672464  ]
#  [ 2.5961313   2.5961313   2.5961313  ... -0.10201772 -0.10201772
#   -0.10201772]
#  [-1.2233262  -1.2233262  -1.2233262  ...  0.64090496  0.64090496
#    0.64090496]
#  ...
#  [-0.49345636 -0.49345636 -0.49345636 ... -0.21353473 -0.21353473
#   -0.21353473]
#  [-0.35418853 -0.35418853 -0.35418853 ...  0.8462496   0.8462496
#    0.8462496 ]
#  [-0.40468702 -0.40468702 -0.40468702 ...  0.9790071   0.9790071
#    0.9790071 ]]
# (20, 216)

# %%
mfcc_delta2 = librosa.feature.delta(mfcc, order=2)
print(mfcc_delta2)
print(mfcc_delta2.shape) # (20, 216)
# Out:
# [[-0.5777732  -0.5777732  -0.5777732  ...  0.17688781  0.17688781
#    0.17688781]
#  [-0.84905815 -0.84905815 -0.84905815 ... -0.2657799  -0.2657799
#   -0.2657799 ]
#  [-0.82673985 -0.82673985 -0.82673985 ... -0.27680838 -0.27680838
#   -0.27680838]
#  ...
#  [ 0.27967688  0.27967688  0.27967688 ...  0.81311375  0.81311375
#    0.81311375]
#  [ 0.48055655  0.48055655  0.48055655 ...  0.5214476   0.5214476
#    0.5214476 ]
#  [ 0.73998743  0.73998743  0.73998743 ...  0.57226354  0.57226354
#    0.57226354]]
# (20, 216)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=3, sharex=True, sharey=True, figsize=(16, 16))

img1 = librosa.display.specshow(mfcc, ax=ax[0], x_axis='time')
ax[0].set(title='MFCC_f')
ax[0].label_outer()

img2 = librosa.display.specshow(mfcc_delta, ax=ax[1], x_axis='time')
ax[1].set(title=r'MFCC-$\Delta$')
ax[1].label_outer()

img3 = librosa.display.specshow(mfcc_delta2, ax=ax[2], x_axis='time')
ax[2].set(title=r'MFCC-$\Delta^2$')

fig.colorbar(img1, ax=[ax[0]])
fig.colorbar(img2, ax=[ax[1]])
fig.colorbar(img3, ax=[ax[2]])
