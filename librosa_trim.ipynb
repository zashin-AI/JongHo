# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# Load some audio
y, sr = librosa.load('C:/nmb/nmb_data/testvoice_F2.wav')

# Trim the beginning and ending silence
yt, index = librosa.effects.trim(y, top_db=1.5)

# Print the durations
print(librosa.get_duration(y), librosa.get_duration(yt))

plt.figure(figsize=(16,6))
plt.subplot(2, 1, 1)
librosa.display.waveplot(y=y, sr=sr)

plt.subplot(2, 1, 2)
librosa.display.waveplot(y=yt, sr=sr)

plt.show()
# Out:
# 5.0 1.207437641723356

# %%
import soundfile as sf

# filepath = 'C:/nmb/nmb_data/F2.wav'
# filepath1 = 'C:/nmb/nmb_data/M2.wav'

# sf.write('C:/nmb/nmb_data/F2.wav', y, sr)
sf.write('C:/nmb/nmb_data/F2_slice.wav', yt, sr)
